# %%
list_1 = [1,2,3,4,5,"Depi","Learing",True, [1,2,3 , "true",["ML" , "DL","GenAi"]] ]
print(type(list_1))
# Out:
# <class 'list'>

# %%
list_1[-1][4][1]
# Out:
# 'DL'

# %%
list_1 = ["depi", "learning", "python"]
list_1.extend("ArithmeticError")
list_1
# Out:
# ['depi',
#  'learning',
#  'python',
#  'A',
#  'r',
#  'i',
#  't',
#  'h',
#  'm',
#  'e',
#  't',
#  'i',
#  'c',
#  'E',
#  'r',
#  'r',
#  'o',
#  'r']

# %%
list_1 = ["depi", "learning", "python"]
my_list = list_1+["machine"]
print(list_1)
print(my_list)
# Out:
# ['depi', 'learning', 'python']
# ['depi', 'learning', 'python', 'machine']

# %%
##Quiz

# %%
input_list = ["amit","learning","python","machine learning","data science","deep learning"]
item = input("Enter the item to be removed: ")
input_list.remove(item)
print(input_list)
# Out:
# ['learning', 'python', 'machine learning', 'data science', 'deep learning']

# %%
# Quiz
num1 = input("Enter the first number: ")
num2 = input("Enter the second number: ")
addition = int(num1) + int(num2)
subtraction = int(num1) - int(num2)
multiplication = int(num1) * int(num2)
division = int(num1) / int(num2)
print("first number: ", num1 ,  "second number: ", num2)
print("Addition: ", addition)
print("Subtraction: ", subtraction)
print("Multiplication: ", multiplication)
print("Division: ", division)
# Out:
# first number:  5 second number:  3
# Addition:  8
# Subtraction:  2
# Multiplication:  15
# Division:  1.6666666666666667
