# %% [markdown]
# ## Input Validation:

# %%
email = input("Enter your email address: ")
if "@"  in email and "."  in email:
    print("Valid email address")
else:
    print("Invalid email address") 
print(f"Email: {email}")
# Out:
# Valid email address
# Email: Amit_ml@gmail.edu

# %% [markdown]
# ## Extract Username:

# %%
username = email.split("@")[0]
print(f"Username: {username}")
# Out:
# Username: Amit_ml

# %% [markdown]
# ## Extract Domain:

# %%
domain = email.split("@")[1]
print(f"Domain: {domain}")
# Out:
# Domain: gmail.edu

# %% [markdown]
# ## Check for Domain Ending:

# %%
if domain.endswith(".com"):
    print("The email address is a commercial domain.")
elif domain.endswith(".edu"):
    print("The email address is an educational domain.")

else:
    print("other domain")
# Out:
# The email address is an educational domain.
