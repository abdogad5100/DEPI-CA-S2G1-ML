# %% [markdown]
# #### Task- per day                                                                                                                                                                                                                                                                                                          ""Problem: Basic Calculator""
# Objective: Create a simple calculator program that can perform basic arithmetic operations: addition, subtraction, multiplication, and division.
#
# ""Requirements:""
# ------------------------
# ""User Input:""
#
# The program should prompt the user to choose an operation from the following list:
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Exit
# Input Validation:
#
# Ensure that the user inputs valid numbers for the calculations. If the input is invalid (e.g., non-numeric), prompt the user to enter the numbers again.
# Performing Calculations:
#
# Based on the user's choice, the program should ask for two numbers and perform the selected operation.
# If the user selects division, check if the second number is zero to avoid division by zero errors.
# Looping:
#
# After each calculation, ask the user if they want to perform another calculation. If they answer "yes," return to the operation selection; if they answer "no," exit the program.
# Output:
#
# Display the result of the calculation in a user-friendly format.
# For example: "The result of adding 5 and 3 is 8."
# Exit Option:
#
# If the user chooses to exit, print a thank you message and terminate the program.

# %%
while True:    
     
    print("choose an operation from the following list:")
    print("1. Addition \n2. Subtraction \n3. Multiplication \n4. Division")

    while True:
        user_input = input("Enter choice (1/2/3/4): ")

        if user_input == '1':
            print(f"You have selected option {user_input}: Addition")
            break

        elif user_input == '2':
            print(f"You have selected option {user_input}: Subtraction")
            break

        elif user_input == '3':
            print(f"You have selected option {user_input}: Multiplication")
            break

        elif user_input == '4':
            print(f"You have selected option {user_input}: Division")
            break

        else:
            print("Invalid input. Please try again.")                 

    print("Enter two numbers:")
    num1= int(input("Enter first number: "))
    num2= int(input("Enter second number: "))
    print("The numbers you have entered are: ", num1, "and", num2)
    
    if(user_input == '1'):
        print(f"The sum of the numbers is:{num1} + {num2} = ", num1 + num2)
    elif(user_input == '2'):
        if num2 < 0:
            print(f"The difference is: {num1} - ({num2}) = {num1 - num2}")
        else:
            print(f"The difference is: {num1} - {num2} = {num1 - num2}")

    elif(user_input == '3'):
        print(f"The product of the numbers is:{num1} x {num2} =", num1 * num2)


    elif(user_input == '4'):
        if(num2 == 0):
            print("Division by zero is not allowed.")
        else:
            print(f"The diviesion of the numbers is:{num1} / {num2} = ", num1 / num2)   

                     
    while True:
        again = input("\nDo you want to calculate again? (yes/no): ").lower()

        if again == "yes":
            break

        elif again == "no":
            print("Exit!")
            break

        else:
            print("Invalid input. Please enter yes or no.")
    if again == "no":
        break
# Out:
# choose an operation from the following list:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# You have selected option 2: Subtraction
# Enter two numbers:
# The numbers you have entered are:  1 and 3
# The difference is: 1 - 3 = -2
# choose an operation from the following list:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# You have selected option 4: Division
# Enter two numbers:
# The numbers you have entered are:  1 and 2
# The diviesion of the numbers is:1 / 2 =  0.5
# Exit!
